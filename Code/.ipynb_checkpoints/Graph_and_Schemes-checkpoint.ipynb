# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.colors import ListedColormap

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
})

# %%
references_df = pd.read_csv('References.csv')
references_df.info
references_df = references_df.dropna(subset=['Topic 1'])
references_df.info
# Out:
# <bound method DataFrame.info of      Ref n°                                            Authors  \
# 0         1                               GM Wagnild, HM Young
# 1         2                         L Campbell‐Sills, MB Stein
# 2         3                     NR Ahern, EM Kiehl, M Lou Sole
# 3         4                      G Windle, KM Bennett, J Noyes
# 4         5              Y Wu, W Yu, X Wu, H Wan, Y Wang, G Lu
# ..      ...                                                ...
# 334     335        Ziemke, T., Schaefer, K. E., & Endsley, M.
# 335     336  Maher, M., Kaziunas, E., Ackerman, M., Derry, ...
# 336     337                          Eakin, H., & Luers, A. L.
# 337     338  Arnold, J. L., Levine, B. N., Manmatha, R., Le...
# 338     339                                      Hollnagel, E.
#
#                                                  Title  Unnamed: 3  \
# 0    Development and Psychometric Evaluation of the...         NaN
# 1    Psychometric analysis and refinement of the co...         NaN
# 2         A review of instruments measuring resilience         NaN
# 3    A methodological review of resilience measurem...         NaN
# 4    Psychological resilience and positive coping s...         NaN
# ..                                                 ...         ...
# 334  Situation awareness in human-machine interacti...         NaN
# 335  User-centered design groups to engage patients...         NaN
# 336  Assessing the Vulnerability of Social-Environm...         NaN
# 337  Information-sharing in out-of-hospital disaste...         NaN
# 338    Resilience engineering in practice: A guidebook         NaN
#
#      Unnamed: 4  Unnamed: 5 Unnamed: 6  Year  Citations      Topic 1  \
# 0           NaN         NaN        NaN  1993     7877.0   Psychology
# 1           NaN         NaN        NaN  2007     3865.0   Psychology
# 2           NaN         NaN        NaN  2006     1231.0   Psychology
# 3           NaN         NaN        NaN  2011     3129.0   Psychology
# 4           NaN         NaN        NaN  2020      229.0   Psychology
# ..          ...         ...        ...   ...        ...          ...
# 334         NaN         NaN        NaN  2017       37.0          CAS
# 335         NaN         NaN        NaN  2016       78.0       Health
# 336         NaN         NaN        NaN  2006     1740.0      Ecology
# 337         NaN         NaN        NaN  2004       75.0       Health
# 338         NaN         NaN        NaN  2013     1136.0  Engineering
#
#          Topic 2 Methodology 1 Methodology 2 Remark
# 0            NaN        Survey           NaN    All
# 1            NaN        Survey           NaN    All
# 2            NaN        Survey           NaN     TN
# 3            NaN        Survey           NaN     TN
# 4            NaN        Survey           NaN    All
# ..           ...           ...           ...    ...
# 334  Engineering          Tech           NaN    NaN
# 335          NaN          Tech           NaN    NaN
# 336      Ecology       Metrics           NaN    NaN
# 337      Climate          Tech           NaN    NaN
# 338          NaN  Case Studies           NaN    NaN
#
# [331 rows x 14 columns]>

# %%
topic_1_list = references_df['Topic 1'].dropna().tolist()
print(topic_1_list)
methodology_1_list = references_df['Methodology 1'].dropna().tolist()
print(methodology_1_list)

print(len(topic_1_list), len(methodology_1_list))

topic_2_list = references_df['Topic 2'].dropna().tolist()
print(topic_2_list)
methodology_2_list = references_df['Methodology 2'].dropna().tolist()
print(methodology_2_list)

print(len(topic_2_list), len(methodology_2_list))

TopicList = topic_1_list + topic_2_list
MethodologyList = methodology_1_list + methodology_2_list
# Out:
# ['Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'CAS', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Math', 'Math', 'Engineering', 'Cyber', 'Climate', 'Engineering', 'Engineering', 'Ecology', 'Ecology', 'Ecology', 'Ecology', 'CAS', 'Org', 'Org', 'Ecology', 'Ecology', 'Health', 'Psychology', 'Health', 'Health', 'Psychology', 'Psychology', 'Health', 'Ecology', 'Climate', 'Ecology', 'Ecology', 'Ecology', 'Climate', 'Climate', 'Ecology', 'Health', 'Climate', 'Health', 'Health', 'Ecology', 'Health', 'Climate', 'Climate', 'Climate', 'Ecology', 'Ecology', 'Engineering', 'Engineering', 'Engineering', 'Ecology', 'Ecology', 'Org', 'Org', 'Cyber', 'Org', 'Ecology', 'CAS', 'Cyber', 'Psychology', 'Psychology', 'Org', 'Engineering', 'Cyber', 'Cyber', 'CAS', 'Cyber', 'Org', 'Org', 'Psychology', 'Cyber', 'Engineering', 'Ecology', 'Ecology', 'Ecology', 'Ecology', 'CAS', 'CAS', 'Physics', 'Physics', 'CAS', 'Ecology', 'CAS', 'Math', 'CAS', 'CAS', 'CAS', 'CAS', 'CAS', 'Engineering', 'Engineering', 'Climate', 'Climate', 'Health', 'Health', 'Health', 'Health', 'Health', 'Health', 'Engineering', 'Engineering', 'Ecology', 'Ecology', 'Climate', 'Ecology', 'Engineering', 'CAS', 'CAS', 'CAS', 'CAS', 'CAS', 'CAS', 'CAS', 'CAS', 'Engineering', 'Engineering', 'Engineering', 'Engineering', 'Ecology', 'Engineering', 'Engineering', 'Engineering', 'Engineering', 'Engineering', 'Engineering', 'Ecology', 'Ecology', 'Ecology', 'Ecology', 'Ecology', 'Climate', 'Climate', 'Climate', 'Climate', 'Climate', 'Climate', 'Climate', 'Climate', 'Climate', 'Climate', 'Climate', 'Climate', 'Health', 'Health', 'Health', 'Health', 'CAS', 'Health', 'Health', 'Health', 'Health', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Cyber', 'Ecology', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Psychology', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Org', 'Cyber', 'Cyber', 'Cyber', 'Cyber', 'Cyber', 'Cyber', 'Cyber', 'Org', 'Org', 'Ecology', 'Org', 'Ecology', 'Org', 'Org', 'Org', 'Psychology', 'Physics', 'Org', 'Cyber', 'Cyber', 'Climate', 'CAS', 'CAS', 'Physics', 'Psychology', 'Psychology', 'Psychology', 'CAS', 'Climate', 'Engineering', 'Org', 'Org', 'Cyber', 'Cyber', 'Cyber', 'Cyber', 'Math', 'Math', 'Math', 'Math', 'Math', 'Math', 'Math', 'Physics', 'Physics', 'Physics', 'Math', 'CAS', 'CAS', 'CAS', 'Engineering', 'Engineering', 'Engineering', 'Engineering', 'Engineering', 'Engineering', 'Ecology', 'Ecology', 'Climate', 'Org', 'Health', 'Org', 'Cyber', 'Org', 'Cyber', 'CAS', 'Cyber', 'CAS', 'Org', 'Org', 'Psychology', 'Org', 'CAS', 'Org', 'CAS', 'Cyber', 'Psychology', 'CAS', 'Health', 'CAS', 'Health', 'CAS', 'CAS', 'CAS', 'CAS', 'Climate', 'Health', 'Health', 'Psychology', 'Climate', 'CAS', 'Health', 'Ecology', 'Health', 'Engineering']
# ['Survey', 'Survey', 'Survey', 'Survey', 'Survey', 'Survey', 'Tech', 'Tech', 'Tech', 'Survey', 'Tech', 'Metrics', 'Survey', 'Survey', 'Survey', 'Survey', 'Survey', 'Metrics', 'Case Studies', 'Case Studies', 'Case Studies', 'Case Studies', 'Long Studies', 'Long Studies', 'Long Studies', 'Long Studies', 'SM', 'SM', 'SM', 'SM', 'Net Analysis', 'Net Analysis', 'Net Analysis', 'Net Analysis', 'Metrics', 'Metrics', 'Tech', 'Metrics', 'SM', 'SM', 'SM', 'SM', 'SM', 'SM', 'Survey', 'SM', 'SM', 'Case Studies', 'Case Studies', 'Case Studies', 'Net Analysis', 'Metrics', 'Tech', 'Case Studies', 'Long Studies', 'Long Studies', 'SM', 'Long Studies', 'Net Analysis', 'Net Analysis', 'Long Studies', 'Net Analysis', 'SM', 'Case Studies', 'Long Studies', 'Case Studies', 'Metrics', 'Case Studies', 'SM', 'Long Studies', 'Long Studies', 'SM', 'SM', 'SM', 'SM', 'Tech', 'Survey', 'Survey', 'Metrics', 'Case Studies', 'SM', 'SM', 'SM', 'Metrics', 'Case Studies', 'Survey', 'Survey', 'Survey', 'Survey', 'Metrics', 'Case Studies', 'Survey', 'Survey', 'Case Studies', 'Survey', 'SM', 'SM', 'Metrics', 'SM', 'Case Studies', 'Survey', 'Case Studies', 'Survey', 'Case Studies', 'Metrics', 'Metrics', 'Case Studies', 'Case Studies', 'Survey', 'SM', 'Net Analysis', 'SM', 'SM', 'SM', 'SM', 'SM', 'SM', 'Case Studies', 'Net Analysis', 'SM', 'Survey', 'Survey', 'Tech', 'Tech', 'Net Analysis', 'Net Analysis', 'Metrics', 'Case Studies', 'Metrics', 'Survey', 'Tech', 'Tech', 'Survey', 'Survey', 'Survey', 'Survey', 'Tech', 'Net Analysis', 'Metrics', 'Survey', 'Case Studies', 'Survey', 'Survey', 'SM', 'Metrics', 'SM', 'Case Studies', 'Survey', 'Survey', 'SM', 'Survey', 'Case Studies', 'SM', 'Survey', 'Case Studies', 'SM', 'Case Studies', 'Survey', 'Case Studies', 'SM', 'SM', 'Tech', 'Case Studies', 'Metrics', 'Survey', 'Survey', 'Case Studies', 'Tech', 'Case Studies', 'Survey', 'Case Studies', 'Survey', 'Survey', 'Tech', 'Long Studies', 'Survey', 'Survey', 'Case Studies', 'Case Studies', 'Survey', 'Case Studies', 'Survey', 'Case Studies', 'Metrics', 'Long Studies', 'Survey', 'Survey', 'Survey', 'Survey', 'Long Studies', 'Long Studies', 'Long Studies', 'Long Studies', 'Long Studies', 'Survey', 'Long Studies', 'Survey', 'Survey', 'Survey', 'Survey', 'Metrics', 'Survey', 'Metrics', 'Case Studies', 'Case Studies', 'Survey', 'Case Studies', 'Case Studies', 'Tech', 'Case Studies', 'Tech', 'Case Studies', 'Case Studies', 'Survey', 'Metrics', 'Tech', 'Survey', 'SM', 'Case Studies', 'Case Studies', 'Case Studies', 'Long Studies', 'Survey', 'Long Studies', 'Case Studies', 'Case Studies', 'Survey', 'Case Studies', 'Survey', 'Case Studies', 'Case Studies', 'Survey', 'Long Studies', 'Net Analysis', 'Long Studies', 'Survey', 'Survey', 'Long Studies', 'Tech', 'Metrics', 'Case Studies', 'SM', 'Net Analysis', 'Survey', 'Case Studies', 'Case Studies', 'Case Studies', 'Survey', 'Survey', 'Survey', 'Case Studies', 'Survey', 'Survey', 'Survey', 'Survey', 'Survey', 'Survey', 'Survey', 'Survey', 'Metrics', 'Tech', 'Survey', 'Survey', 'SM', 'Metrics', 'SM', 'Tech', 'Case Studies', 'Survey', 'Survey', 'Case Studies', 'Survey', 'SM', 'Net Analysis', 'SM', 'Survey', 'SM', 'SM', 'SM', 'Survey', 'Metrics', 'SM', 'SM', 'Survey', 'SM', 'Case Studies', 'Survey', 'Survey', 'SM', 'Case Studies', 'Survey', 'Metrics', 'Survey', 'Metrics', 'Case Studies', 'Survey', 'Case Studies', 'Survey', 'Survey', 'Survey', 'Case Studies', 'Survey', 'Survey', 'Survey', 'Case Studies', 'Tech', 'Tech', 'Case Studies', 'Case Studies', 'Case Studies', 'Survey', 'Survey', 'Tech', 'Net Analysis', 'SM', 'SM', 'SM', 'Net Analysis', 'Net Analysis', 'SM', 'SM', 'SM', 'Long Studies', 'Long Studies', 'Tech', 'Case Studies', 'Tech', 'Tech', 'Metrics', 'Tech', 'Case Studies']
# 331 331
# ['CAS', 'Ecology', 'Cyber', 'Cyber', 'Climate', 'Health', 'Health', 'Health', 'Climate', 'Cyber', 'Cyber', 'Climate', 'Engineering', 'Climate', 'Cyber', 'Climate', 'Cyber', 'Climate', 'Cyber', 'Engineering', 'Ecology', 'Ecology', 'CAS', 'Climate', 'CAS', 'Org', 'CAS', 'CAS', 'CAS', 'CAS', 'Ecology', 'Ecology', 'Engineering', 'Ecology', 'Org', 'Cyber', 'Cyber', 'Health', 'Cyber', 'Ecology', 'Org', 'Ecology', 'Ecology', 'Ecology', 'CAS', 'Cyber', 'Cyber', 'Engineering', 'Engineering', 'Cyber', 'CAS', 'Cyber', 'Cyber', 'Org', 'Cyber', 'Ecology', 'Climate', 'Climate', 'Org', 'Cyber', 'Org', 'Org', 'Psychology', 'Cyber', 'Org', 'Org', 'Engineering', 'Org', 'Cyber', 'Engineering', 'Health', 'Ecology', 'Ecology', 'Ecology', 'Climate', 'Climate', 'Ecology', 'Engineering', 'Ecology', 'Climate']
# ['SM', 'Net Analysis', 'Long Studies', 'Long Studies', 'Case Studies', 'Long Studies', 'Net Analysis', 'Net Analysis', 'Case Studies', 'Case Studies', 'Survey', 'Case Studies', 'Tech', 'Survey', 'Case Studies', 'Net Analysis', 'Case Studies', 'Case Studies', 'SM', 'Case Studies', 'Survey', 'Metrics', 'SM', 'Case Studies', 'Survey', 'Metrics', 'Survey', 'Metrics', 'Metrics', 'Case Studies', 'Net Analysis', 'Case Studies', 'Metrics', 'Metrics', 'Case Studies', 'Survey', 'Survey', 'Case Studies', 'Survey', 'Survey', 'Survey', 'Survey', 'Survey', 'Net Analysis', 'Metrics', 'Survey', 'Metrics', 'Metrics', 'Survey', 'Survey', 'Case Studies', 'Survey', 'Survey', 'Survey', 'Metrics', 'Survey', 'Survey', 'Case Studies', 'Net Analysis', 'Net Analysis']
# 80 60

# %%
contingency_table = pd.crosstab(pd.Series(TopicList, name='Topic'), pd.Series(MethodologyList, name='Methodology'))
print(contingency_table)
# Out:
# Methodology  Case Studies  Long Studies  Metrics  Net Analysis  SM  Survey  \
# Topic
# CAS                     9             0        4             5  14      15
# Climate                12             2        3             3   3      10
# Cyber                   9             3        4             2   4      19
# Ecology                15             1        8             5   7      10
# Engineering             5             0        5             0  11      12
# Health                  7             7        3             2   6       4
# Math                    0             0        0             1   9       1
# Org                    22             3        3             3   1      22
# Physics                 0             0        2             0   3       2
# Psychology              5            13        7             6   4      26
#
# Methodology  Tech
# Topic
# CAS             1
# Climate         4
# Cyber           1
# Ecology         2
# Engineering     3
# Health          4
# Math            0
# Org             5
# Physics         0
# Psychology      9

# %%
# Reorder the rows and columns of the contingency table
reordered_contingency_table = contingency_table.reindex(['Math', 'Physics', 'CAS', 'Engineering', 'Ecology','Climate', 'Health', 'Psychology', 'Org', 'Cyber'] + [topic for topic in contingency_table.index if topic not in ['Math', 'Physics', 'CAS', 'Engineering', 'Ecology','Climate', 'Health', 'Psychology', 'Org', 'Cyber']])
reordered_contingency_table = reordered_contingency_table[['SM', 'Net Analysis', 'Metrics', 'Tech', 'Case Studies', 'Long Studies', 'Survey'] + [col for col in reordered_contingency_table.columns if col not in ['SM', 'Net Analysis', 'Metrics', 'Tech', 'Case Studies', 'Long Studies', 'Survey']]]

cmap = sns.color_palette("Blues", as_cmap=True)
white = np.array([1, 1, 1, 1])
cmap.set_under(white)

# Plot the heatmap with reordered data
plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(reordered_contingency_table, annot=True, fmt='d',linewidth=.5, cmap=cmap, vmin=0)
heatmap.set_xlabel('Methodologies', fontsize=20)
heatmap.set_ylabel('Topics', fontsize=20)
heatmap.tick_params(axis='both', which='major', labelsize=16)

cbar = heatmap.collections[0].colorbar
cbar.ax.tick_params(labelsize=14)
cbar.set_label(r'Number of references', fontsize=18)

desired_order_y = ['Mathematics', 'Physics', 'Complex Adaptive Systems', 'Engineering', 'Ecology and Social Systems', 'Climate Change and Disaster', 'Public Health', 'Psychology and Neuroscience', 'Organizations Management', 'Cyber and Risk Management']
desired_order_x = ['Simulation and Modeling', 'Network Analysis', 'Markers and Metrics Measurement', 'Technological Assessment', 'Case Studies', 'Longitudinal Studies', 'Survey']
heatmap.set_yticklabels(desired_order_y, rotation=0, horizontalalignment='right')
heatmap.set_xticklabels(desired_order_x, rotation=45, horizontalalignment='right')
#heatmap.set_yticklabels(desired_order, rotation=0)


plt.savefig('HeatMap_SoA.pdf',dpi=300, bbox_inches = "tight")

plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.histplot(references_df['Year'], bins=25, kde=False)
plt.xlabel('Year of Publication', fontsize=20)
plt.ylabel('Number of Publications', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
